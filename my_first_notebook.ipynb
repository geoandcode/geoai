# %%
# !git add .

# %%
# !git commit -m "added project folder"
# Out:
# [cleanbranch fa5a89c] added project folder
#  4 files changed, 129 insertions(+), 207 deletions(-)
#  rewrite my_first_notebook.ipynb (85%)
#  rename portfolio/.ipynb_checkpoints/{Untitled-checkpoint.ipynb => empty-checkpoint.ipynb} (100%)
#  delete mode 100644 portfolio/Untitled.ipynb
#  create mode 100644 portfolio/empty.ipynb

# %% [markdown]
# !git push
