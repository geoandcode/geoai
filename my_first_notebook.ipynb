# %% [markdown]
# !git push -u origin master --force===

# %% [markdown]
# !git rev-parse --show-toplevel

# %%
# !git add .

# %% [markdown]
# !git commit -m "added project folder"

# %% [markdown]
# !git push
