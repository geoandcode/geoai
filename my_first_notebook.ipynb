# %%
# !git add .

# %%
# !git commit -m "added project folder"
# Out:
# [cleanbranch 82cfdfa] added project folder
#  1 file changed, 18 insertions(+), 27 deletions(-)

# %%
# !git push
# Out:
# Enumerating objects: 13, done.
# Counting objects: 100% (13/13), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 1.74 KiB | 1.74 MiB/s, done.
# Total 9 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 1 local object.
# To https://github.com/geoandcode/geoai.git
#    157937d..82cfdfa  cleanbranch -> cleanbranch
